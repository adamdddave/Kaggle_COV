# %%
import pandas as pd
import matplotlib
# %matplotlib inline
from matplotlib import pyplot as plt
import wordcloud
import numpy as np

# %%
df = pd.read_csv("../2020-03-13/all_sources_metadata_2020-03-13.csv")

# %%
df = df[df['abstract'].notnull()]

# %%
df['abstract'] = df.apply(lambda x : x.abstract.replace(".","").replace(",","").lower().split(),axis=1)

# %%
from collections import Counter
z = Counter()
#print(z)
for _,row in df.iterrows():
    #print(row)
    z+=Counter(row['abstract'])
#print(z)

# %%
#make a function to do the frequency map
#https://amueller.github.io/word_cloud/auto_examples/frequency.html#sphx-glr-auto-examples-frequency-py
def makeImage(text):
    wc = wordcloud.WordCloud(width=1600, height=800,background_color="black")
    # generate word cloud
    wc.generate_from_frequencies(text)
    # show
    #stuff=plt.imshow(wc, interpolation="bilinear")
    fig=plt.figure(figsize=(20,10), facecolor='k')
    plt.imshow(wc)
    plt.axis("off")
    plt.tight_layout(pad=0)
    plt.show()
    fig.savefig("test.pdf",bbox_inches='tight',facecolor='k')

# %%
makeImage(z)

# %%
z['the']
# Out:
# 0

# %%
for thing in ['a','the','an','the','to','in','for','of','or','by','with','is','on','that','be','were','and','was','are','is','as','we','from','this','these','have','which','at','not','their','our','but','has','been','can','also','than','virus','viral','infection','may','viruses','they','will','had','while']:
    z[thing]=0

# %%
makeImage(z)
